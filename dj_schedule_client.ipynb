# %%
#This notebook runs independently of the EC2 instance, and is intended to be run on a local machine with access to AWS credentials.

# %%
#When prompted, select SCU email and confirm.
import os
import gspread
import pandas as pd
from google.colab import auth
from google.auth import default

auth.authenticate_user()

creds, _ = default()

gc = gspread.authorize(creds)

# %%
ls
# Out:
# "Copy of KSCU STAFF Summer '25 DJ Application.gform"
# "Copy of KSCU Staff Winter '25 DJ Application.gform"
# "Copy of KSCU Summer '25 DJ Application.gform"
# "Copy of KSCU Winter '25 DJ Application.gform"
# 'Copy of KSCU Winter '\''25 DJ Application (Responses).gsheet'
# "KSCU Fall '25 DJ Application.gform"
# "KSCU Final Summer '25 DJ Application and Schedule.gsheet"
# "KSCU Spring '25 Access Numbers.gdoc"
# 'KSCU Spring '\''25 DJ Application (Responses).gsheet'
# "KSCU STAFF Fall '25 DJ Application.gform"
# "KSCU STAFF Summer '25 DJ Application.gform"
# "KSCU Staff Winter '25 DJ Application.gform"
# "KSCU Summer '25 DJ Application.gform"
# 'KSCU Summer (and spring) '\''25 DJ Application (Responses) .gsheet'
# "KSCU Winter '25 DJ Application.gform"
# 'KSCU Winter '\''25 DJ Application (Responses).gsheet'
# 'Programming Director Guide.gdoc'

# %%
#Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Make sure this points to where the schedule sheet is located.
# %cd"Filepath"
# Out:
# /content/drive/Shareddrives/KSCU Main Drive/Archive/24-25 Archive/Programming Director

# %%
ls
# Out:
# "Copy of KSCU STAFF Summer '25 DJ Application.gform"
# "Copy of KSCU Staff Winter '25 DJ Application.gform"
# "Copy of KSCU Summer '25 DJ Application.gform"
# "Copy of KSCU Winter '25 DJ Application.gform"
# 'Copy of KSCU Winter '\''25 DJ Application (Responses).gsheet'
# "KSCU Fall '25 DJ Application.gform"
# "KSCU Final Summer '25 DJ Application and Schedule.gsheet"
# "KSCU Spring '25 Access Numbers.gdoc"
# 'KSCU Spring '\''25 DJ Application (Responses).gsheet'
# "KSCU STAFF Fall '25 DJ Application.gform"
# "KSCU STAFF Summer '25 DJ Application.gform"
# "KSCU Staff Winter '25 DJ Application.gform"
# "KSCU Summer '25 DJ Application.gform"
# 'KSCU Summer (and spring) '\''25 DJ Application (Responses) .gsheet'
# "KSCU Winter '25 DJ Application.gform"
# 'KSCU Winter '\''25 DJ Application (Responses).gsheet'
# 'Programming Director Guide.gdoc'

# %%
import sqlite3

#Change this filename to the name of the google sheet.
filename = "DJ schedule filename"

sh = gc.open(filename).get_worksheet(3);
if (sh):
  rows = sh.get_all_values()
  # Convert to pandas dataframe
  df = pd.DataFrame(rows[1:], columns=rows[0])

  nanValue = float("NaN")
  df.replace("", nanValue, inplace=True)

  #drop any empty columns from the dataframe
  df.dropna(how='all', axis=1, inplace=True)

  display(df)
  # Save to SQLite file

  dbFileName = filename.replace(" ", "_").replace("'", "").lower() + '.db'

  sqliteConn = sqlite3.connect(dbFileName)
  cursor = sqliteConn.cursor()
  sh2 = df.to_sql(name="shows", con=sqliteConn, if_exists='replace', index=False)
  sqliteConn.close()

  print("Google Sheet successfully converted to " + dbFileName)
else:
  print("Schedule file not found. Ensure the file is a google sheet and the path is correct.")
# Out:
# /tmp/ipython-input-3063252048.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("", nanValue, inplace=True)
#     New DJ?     Day           Timeslot                     Email  \
# 0       NaN  Monday        7:00-8:00 AM       fjsaunders@scu.edu
# 1     FALSE  Monday        8:00-9:00 AM  Nikhita.loves@gmail.com
# 2     FALSE   Monday      9:00-10:00 AM           ambell@scu.edu
# 3     FALSE   Monday     10:00-11:00 AM       krmartinez@scu.edu
# 4     FALSE   Monday  11:00 AM-12:00 PM         ngarcia2@scu.edu
# ..      ...      ...                ...                      ...
# 138   FALSE   Sunday    9:00 - 10:00 PM         cjhudson@scu.edu
# 139   FALSE   Sunday      9:00-10:00 PM       Memcgivney@scu.edu
# 140    TRUE   Sunday      10:00 - 11 PM           azchen@scu.edu
# 141    TRUE   Sunday         11 PM-12AM            llash@scu.edu
# 142   FALSE   Sunday       12 AM - 1 AM           ssood2@scu.edu
#
#                  Name          Show Title      DJ Name
# 0    Felicia Saunders          Open Water         Fish
# 1    Nikhita Panjnani   It’s a Love Story     DJ Lover
# 2       Allyson Bell              DJ Ally      DJ Ally
# 3      Karla Martinez       Cherrypicked       DJ Ruby
# 4      Natasha Garcia             The Zoo  Miss Monkey
# ..                ...                 ...          ...
# 138      Clara Hudson         Stay Awhile    Dj Chuddy
# 139      Mae Mcgivney         Stay Awhile   Dj mae mae
# 140        Alena Chen        Mist & Twist         Mist
# 141         lila lash           lila lash     lilalash
# 142       Sanjna Sood  Plutos Indie Orbit     DJ Pluto
#
# [143 rows x 7 columns]
# Google Sheet successfully converted to kscu_winter_25_dj_application_(responses).db

# %%
#Run this ONLY if AWS credentials have changed. See 'PASSWORDS' file in the KSCU drive if you run into errors later.
import awscli

# !aws configure
# Out:
# AWS Access Key ID [****************2OEF]:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/awscli/clidriver.py", line 234, in main
#     return command_table[parsed_args.command](remaining, parsed_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/awscli/customizations/commands.py", line 188, in __call__
#     return self._run_main(parsed_args, parsed_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/awscli/customizations/configure/configure.py", line 108, in _run_main
#     new_value = self._prompter.get_value(current_value, config_name,
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/awscli/customizations/configure/configure.py", line 42, in get_value
#     response = compat_input("%s [%s]: " % (prompt_text, current_value))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/awscli/compat.py", line 189, in compat_input
#     return raw_input()
#            ^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/aws", line 27, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/bin/aws", line 23, in main
#     return awscli.clidriver.main()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/awscli/clidriver.py", line 74, in main
#     rc = driver.main()
#          ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/awscli/clidriver.py", line 257, in main
#     sys.stdout.write("\n")
# KeyboardInterrupt
# ^C

# %%
#Send the new database file to the S3 (object storage) bucket in AWS.
import boto3
import os

s3 = boto3.resource('s3')
bucket = s3.Bucket("kscu")
dbPath = "schedule/" + dbFileName
currentPath = "schedule/"
archivePath = "schedule-archive/"

objectsToArchive = list(bucket.objects.filter(Prefix=currentPath))

if objectsToArchive:
    for obj in objectsToArchive:
        copy_source = {"Bucket": obj.bucket_name, "Key": obj.key}
        new_key = archivePath + obj.key.split('/')[-1]
        bucket.copy(copy_source, new_key)
        bucket.Object(obj.key).delete()
    print("Previous schedule(s) archived.")

bucket.upload_file(dbFileName, dbPath)

#Remove the transient google drive database
os.remove(dbFileName)
print("New schedule uploaded.")
# Out:
# Previous schedule(s) archived.
# New schedule uploaded.

# %%
#Create an SQS message queue to tell EC2 to grab this new file from S3 storage.

import json

sqs = boto3.resource('sqs', region_name='us-west-1')
queue = sqs.get_queue_by_name(QueueName='new-schedule-msg')
print(queue.url)

msgBody = json.dumps({
    "bucket": "kscu",
    "key": dbPath
})

response = queue.send_message(MessageBody=msgBody)
print("Notification sent to EC2. Message ID:", response.get('MessageId'))
# Out:
# https://sqs.us-west-1.amazonaws.com/409039182201/new-schedule-msg
# Notification sent to EC2. Message ID: d1938e2b-9421-4204-a165-4744f517e3cb
